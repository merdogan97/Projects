# %% [markdown]
# <a href="https://colab.research.google.com/github/merdogan97/Projects/blob/main/DAwPY___Pokemon_Notebook_23_02_2022.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
data= pd.read_csv("/content/Pokemon.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 13 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Type 2      414 non-null    object
#  4   Total       800 non-null    int64
#  5   HP          800 non-null    int64
#  6   Attack      800 non-null    int64
#  7   Defense     800 non-null    int64
#  8   Sp. Atk     800 non-null    int64
#  9   Sp. Def     800 non-null    int64
#  10  Speed       800 non-null    int64
#  11  Generation  800 non-null    int64
#  12  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(3)
# memory usage: 75.9+ KB

# %% [markdown]
# **** Correlation helps us in determining the degree of relationship between variables. It enables us to make our decision for the future course of actions. (ii) Correlation analysis helps us in understanding the nature and degree of relationship which can be used for future planning and forecasting.**

# %% [markdown]
# * Correlation is a statistical measure that expresses the extent to which two variables are linearly related (meaning they change together at a constant rate). It's a common tool for describing simple relationships without making a statement about cause and effect.
# * Correlation is used to describe the linear relationship between two continuous variables (e.g., height and weight). In general, correlation tends to be used when there is no identified response variable. It measures the strength (qualitatively) and direction of the linear relationship between two or more variables.

# %% [markdown]
# * Correlation analysis measures how two variables are related. Thecorrelation coefficient (r) is a statistic that tells you the strengthand direction of that relationship. ...
# * r = 0 means there is no correlation.
# * r = 1 means there is perfect positive correlation.
# * r = -1 means there is a perfect negative correlation.

# %% [markdown]
# # **CORRELATION MAP**

# %%
f,ax = plt.subplots(figsize=(12, 8))
sns.heatmap(data.corr(), annot=True, linewidths=.5, fmt= '.1f',ax=ax)
plt.show()

# %%
data.head(10)
# Out:
#    #                       Name Type 1  ... Speed  Generation  Legendary
# 0  1                  Bulbasaur  Grass  ...    45           1      False
# 1  2                    Ivysaur  Grass  ...    60           1      False
# 2  3                   Venusaur  Grass  ...    80           1      False
# 3  3      VenusaurMega Venusaur  Grass  ...    80           1      False
# 4  4                 Charmander   Fire  ...    65           1      False
# 5  5                 Charmeleon   Fire  ...    80           1      False
# 6  6                  Charizard   Fire  ...   100           1      False
# 7  6  CharizardMega Charizard X   Fire  ...   100           1      False
# 8  6  CharizardMega Charizard Y   Fire  ...   100           1      False
# 9  7                   Squirtle  Water  ...    43           1      False
#
# [10 rows x 13 columns]

# %%
data.sample(10)
# Out:
#        #                   Name    Type 1  ... Speed  Generation  Legendary
# 426  384  RayquazaMega Rayquaza    Dragon  ...   115           3       True
# 654  593              Jellicent     Water  ...    60           5      False
# 10     8              Wartortle     Water  ...    58           1      False
# 741  673                 Gogoat     Grass  ...    68           6      False
# 471  424                Ambipom    Normal  ...   115           4      False
# 183  169                 Crobat    Poison  ...   130           2      False
# 534  479       RotomFrost Rotom  Electric  ...    86           4      False
# 132  123                Scyther       Bug  ...   105           1      False
# 487  439               Mime Jr.   Psychic  ...    60           4      False
# 83    77                 Ponyta      Fire  ...    90           1      False
#
# [10 rows x 13 columns]

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary'],
#       dtype='object')

# %% [markdown]
# <a id="2"></a> <br>
# # **MATPLOTLIB**
#
# * Line plot is better when x axis is time.
# * Scatter is better when there is correlation between two variables
# * Histogram is better when we need to see distribution of numerical data.
# * Customization: Colors,labels,thickness of line, title, opacity, grid, figsize, ticks of axis and linestyle

# %% [markdown]
# # **LINE PLOT**

# %%
f,ax = plt.subplots(figsize=(14, 4))
data.Speed.plot(kind = 'line', color = 'darkblue', label = 'Speed',linewidth=1.5,alpha =1, grid = True,linestyle = '--')
data.Defense.plot(color = 'orange',label = 'Defense',linewidth=1.5, alpha = 0.9,grid = True,linestyle = '--')
plt.legend(loc='upper right')    
plt.xlabel('x axis')          
plt.ylabel('y axis')
plt.title('Line Plot')          
plt.show()

# %% [markdown]
# # **SCATTER PLOT**

# %%
# x = attack, y = defense
data.plot(kind='scatter', x='Attack', y='Defense',alpha = 0.5,color = 'red')
plt.xlabel('Attack')              # label = name of label
plt.ylabel('Defence')
plt.title('Attack Defense Scatter Plot')
# Out:
# Text(0.5, 1.0, 'Attack Defense Scatter Plot')

# %% [markdown]
# # **HISTOGRAM PLOT**

# %%
data.Speed.plot(kind = 'hist',bins = 50,figsize = (10,6)) # bins = number of bar in figure
plt.show()
# plt.clf()

# %% [markdown]
# # **DICTIONARY**
# DataFrame gibi içide "key" ve "Value" değerlerini barındırıyor.
# Faster than lists.
# dict= {"spain": ""madrid"}
# key:spain, value:madrid

# %%
dictionary = {'spain' : 'madrid','usa' : 'vegas'}
print(dictionary.keys())
print(dictionary.values())
# Out:
# dict_keys(['spain', 'usa'])
# dict_values(['madrid', 'vegas'])

# %%
# Keys have to be immutable objects like string, boolean, float, integer or tubles
# List is not immutable
# Keys are unique
dictionary['spain'] = "barcelona"    # update existing entry
print(dictionary)
# Out:
# {'spain': 'barcelona', 'usa': 'vegas'}

# %%
dictionary['france'] = "paris"       # Add new entry
print(dictionary)
# Out:
# {'spain': 'barcelona', 'usa': 'vegas', 'france': 'paris'}

# %%
del dictionary['spain']              # remove entry with key 'spain'
print(dictionary)
# Out:
# {'usa': 'vegas', 'france': 'paris'}

# %%
print('france' in dictionary)   # check include or not
# Out:
# True

# %%
dictionary.clear()                   # remove all entries in dict
print(dictionary)
# Out:
# {}

# %% [markdown]
# # **PANDAS**

# %%
data
# Out:
#        #                   Name   Type 1  ... Speed  Generation  Legendary
# 0      1              Bulbasaur    Grass  ...    45           1      False
# 1      2                Ivysaur    Grass  ...    60           1      False
# 2      3               Venusaur    Grass  ...    80           1      False
# 3      3  VenusaurMega Venusaur    Grass  ...    80           1      False
# 4      4             Charmander     Fire  ...    65           1      False
# ..   ...                    ...      ...  ...   ...         ...        ...
# 795  719                Diancie     Rock  ...    50           6       True
# 796  719    DiancieMega Diancie     Rock  ...   110           6       True
# 797  720    HoopaHoopa Confined  Psychic  ...    70           6       True
# 798  720     HoopaHoopa Unbound  Psychic  ...    80           6       True
# 799  721              Volcanion     Fire  ...    70           6       True
#
# [800 rows x 13 columns]

# %%
series = data['Defense']        # data['Defense'] = series
print(type(series))
data_frame = data[['Defense']]  # data[['Defense']] = data frame
print(type(data_frame))
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
# Comparison operator  : ==, <, >, <=
print(3 > 2)
print(3!=2)
print( 2 == 2)
# Boolean operators  : and, or ,not
print(True and False)
print(True or False)
# Out:
# True
# True
# True
# False
# True

# %% [markdown]
# # **FILTERING:**

# %%
x = data["Defense"]> 200
x
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Defense, Length: 800, dtype: bool

# %%
x = data["Defense"]>200
data[x]             # bu şekilde sadece true olanları yazdırır. False ları ignore eder
# Out:
#        #                 Name Type 1  ... Speed  Generation  Legendary
# 224  208  SteelixMega Steelix  Steel  ...    30           2      False
# 230  213              Shuckle    Bug  ...     5           2      False
# 333  306    AggronMega Aggron  Steel  ...    50           3      False
#
# [3 rows x 13 columns]

# %%
a = (data["Speed"]> 50) & (data["Speed"] < 55)
data[a]
# Out:
#        #                   Name Type 1  ... Speed  Generation  Legendary
# 266  247                Pupitar   Rock  ...    51           2      False
# 390  357                Tropius  Grass  ...    51           3      False
# 402  367                Huntail  Water  ...    52           3      False
# 403  368               Gorebyss  Water  ...    52           3      False
# 738  670                Floette  Fairy  ...    52           6      False
# 740  672                 Skiddo  Grass  ...    52           6      False
# 780  710  PumpkabooAverage Size  Ghost  ...    51           6      False
# 787  711    GourgeistSuper Size  Ghost  ...    54           6      False
#
# [8 rows x 13 columns]

# %%
a = ((data["Speed"]> 50) & (data["Speed"] < 55)).value_counts()
a
# Out:
# False    792
# True       8
# Name: Speed, dtype: int64

# %%
b  = data["Speed"]< 10
data[b]
# Out:
#        #      Name  Type 1 Type 2  ...  Sp. Def  Speed  Generation  Legendary
# 230  213   Shuckle     Bug   Rock  ...      230      5           2      False
# 495  446  Munchlax  Normal    NaN  ...       85      5           4      False
#
# [2 rows x 13 columns]

# %%
data["Defense"]>200
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 795    False
# 796    False
# 797    False
# 798    False
# 799    False
# Name: Defense, Length: 800, dtype: bool

# %% [markdown]
# # **Filtering pandas with logical_and**

# %%
d = np.logical_and(data['Defense']>200, data['Attack']>100 )
data[d]

# data[np.logical_and(data['Defense']>200, data['Attack']>100 )]

# 2 koşulun sağlanması için logical_and kulanırız. True & True döndürecek. (sadece 2tane var)
# Data içine sokunca sadece True olanları getiriyor.
# Out:
#        #                 Name Type 1  ... Speed  Generation  Legendary
# 224  208  SteelixMega Steelix  Steel  ...    30           2      False
# 333  306    AggronMega Aggron  Steel  ...    50           3      False
#
# [2 rows x 13 columns]

# %%
# or:
data[(data["Defense"] > 200) & (data["Attack"] > 100)]
# Out:
#        #                 Name Type 1  ... Speed  Generation  Legendary
# 224  208  SteelixMega Steelix  Steel  ...    30           2      False
# 333  306    AggronMega Aggron  Steel  ...    50           3      False
#
# [2 rows x 13 columns]

# %%
data[np.logical_and(data['Defense']>100, data['Attack']<120)]
# Out:
#        #                     Name  Type 1  ... Speed  Generation  Legendary
# 3      3    VenusaurMega Venusaur   Grass  ...    80           1      False
# 12     9  BlastoiseMega Blastoise   Water  ...    78           1      False
# 33    28                Sandslash  Ground  ...    65           1      False
# 81    75                 Graveler    Rock  ...    35           1      False
# 86    80                  Slowbro   Water  ...    30           1      False
# ..   ...                      ...     ...  ...   ...         ...        ...
# 787  711      GourgeistSuper Size   Ghost  ...    54           6      False
# 789  713                  Avalugg     Ice  ...    28           6      False
# 794  718         Zygarde50% Forme  Dragon  ...    95           6       True
# 795  719                  Diancie    Rock  ...    50           6       True
# 799  721                Volcanion    Fire  ...    70           6       True
#
# [93 rows x 13 columns]

# %% [markdown]
# # **WHILE and FOR LOOPS**

# %% [markdown]
# **while ==> i=0, i+=1**

# %%
i = 0
while i != 5 :
    print('i is: ',i)
    i +=1
print(i,' is equal to 5')
# Out:
# i is:  0
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# 5  is equal to 5

# %% [markdown]
# **List ==> FOR**

# %%
lis = [1,2,3,4,5]
for i in lis:
    print('i is: ',i)
print('')
# Out:
# i is:  1
# i is:  2
# i is:  3
# i is:  4
# i is:  5

# %% [markdown]
# # **enumarate:  değerler index içine depolanıyor**

# %%
list1 = [1,3,5,7,9,11]
for index, value in enumerate(list1):        # Enumerate index and value of list
    print(index," : ",value)                 # index : value = 0:1, 1:2, 2:3, 3:4, 4:5
print('')
# Out:
# 0  :  1
# 1  :  3
# 2  :  5
# 3  :  7
# 4  :  9
# 5  :  11

# %% [markdown]
# **For dictionaries : **
# # **dictionary.items()**

# %%
dictionary = {'spain':'madrid','france':'paris'}  # Çok büyük olduğunu düşün
for key,value in dictionary.items():
    print(key," : ",value)
print('')
# Out:
# spain  :  madrid
# france  :  paris

# %% [markdown]
# # **# achieve index and value**
#
# # **iterrows():**

# %%
for index, value in data[['Attack']][0:3].iterrows():
        print(index," : ", value)
# Ne ? Attack değerini,  Value buluyor, indexini de buluyor ve bana yazdırıyor.
# Out:
# 0  :  Attack    49
# Name: 0, dtype: int64
# 1  :  Attack    62
# Name: 1, dtype: int64
# 2  :  Attack    82
# Name: 2, dtype: int64

# %% [markdown]
# # **USER DEFİNED FUNCTION**

# %% [markdown]
# What do we need to know about functions:
#
# docstrings: documentation for functions. Example:
# for f():
# """This is docstring for documentation of function f"""
# tuple: sequence of immutable python objects.
# cant modify values
# tuple uses paranthesis like tuble = (1,2,3)
# unpack tuple into several variables like a,b,c = tuple

# %%
def tuple_ex():
    """ return defined t tuple"""
    t = (1,2,3)
    return t
a,b,c = tuple_ex()
print(a,b,c)
# Out:
# 1 2 3

# %% [markdown]
# # **# SCOPE**
#
#
# global: defined main body in script
#
# local: defined in a function
#
# built in scope: names in predefined built in scope module such as print, len

# %%
x = 2
def f():
    x = 3
    return x
print(x)          # x = 2 global scope
print(f())        # x = 3 local scope
# Out:
# 2
# 3

# %%
# What if there is no local scope
x = 5
def f():
    y = 2*x        # there is no local scope x
    return y
print(f())         # it uses global scope x  
# First local scope searched, then global scope searched, if two of them cannot be found lastly built in scope searched.
# Out:
# 10

# %%
# How can we learn what is built in scope
import builtins
dir(builtins)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EnvironmentError',
#  'Exception',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
#  'PermissionError',
#  'ProcessLookupError',
#  'RecursionError',
# ...

# %% [markdown]
# # **NESTED FUNCTION**

# %%
def square():
    """ return square of value """
    def add():
        """ add two local variable """
        x = 2
        y = 3
        z = x + y
        return z
    return add()**2
print(square())
# Out:
# 25

# %% [markdown]
# DEFAULT and FLEXIBLE ARGUMENTS
# Default argument example:
# def f(a, b=1):
#   """ b = 1 is default argument"""
# Flexible argument example:
# def f(*args):
#  """ *args can be one or more"""
#
# def f(** kwargs)
#  """ **kwargs is a dictionary"""

# %%
# default arguments
def f(a, b = 1, c = 2):
    y = a + b + c
    return y
print(f(5))
# what if we want to change default arguments
print(f(5,4,3))
# Out:
# 8
# 12

# %%
# flexible arguments *args
def f(*args):
    for i in args:
        print(i)
f(1)
print("")
f(1,2,3,4)
# flexible arguments **kwargs that is dictionary
def f(**kwargs):
    """ print key and value of dictionary"""
    for key, value in kwargs.items():               # If you do not understand this part turn for loop part and look at dictionary in for loop
        print(key, " ", value)
f(country = 'spain', capital = 'madrid', population = 123456)
# Out:
# 1
#
# 1
# 2
# 3
# 4
# country   spain
# capital   madrid
# population   123456

# %% [markdown]
# # **LAMBDA FUNCTION**

# %%
square = lambda x: x**2     
print(square(4))
tot = lambda x,y,z: x+y+z  
print(tot(1,2,3))
# Out:
# 16
# 6

# %% [markdown]
# # **ANONYMOUS FUNCTİON**

# %%
number_list = [1,2,3]
y = map(lambda x:x**2,number_list)
print(list(y))
# Out:
# [1, 4, 9]

# %% [markdown]
# # **ITERATORS**
# iterable is an object that can return an iterator
# iterable: an object with an associated iter() method
# example: list, strings and dictionaries
# iterator: produces next value with next() method

# %%
# iteration example
name = "ronaldo"
it = iter(name)
print(next(it))    # print next iteration
print(*it)         # print remaining iteration
# Out:
# r
# o n a l d o

# %% [markdown]
# # **zip(): zip lists**

# %%
list1 = [1,2,3,4]
list2 = [5,6,7,8]
z = zip(list1,list2)
print(z)
z_list = list(z)
print(z_list)
# Out:
# ...
# [(1, 5), (2, 6), (3, 7), (4, 8)]

# %%
un_zip = zip(*z_list)
un_list1,un_list2 = list(un_zip) # unzip returns tuple
print(un_list1)
print(un_list2)
print(type(un_list2))
# Out:
# (1, 2, 3, 4)
# (5, 6, 7, 8)
# <class 'tuple'>

# %% [markdown]
# # **LIST COMPREHENSİON**
# One of the most important topic of this kernel
#
# We use list comprehension for data analysis often.
#
# list comprehension: collapse for loops for building lists into a single line
#
# Ex: num1 = [1,2,3] and we want to make it num2 = [2,3,4]. This can be done with for loop. However it is unnecessarily long. We can make it one line code that is list comprehension.

# %%
num1 = [1,2,3]
num2 = [i + 1 for i in num1 ]
print(num2)
# Out:
# [2, 3, 4]

# %% [markdown]
# [i + 1 for i in num1 ]: list of comprehension
#
# i +1: list comprehension syntax
#
# for i in num1: for loop syntax
#
# i: iterator
#
# num1: iterable object

# %% [markdown]
# #  **Conditionals on iterable**

# %%
num1 = [5,10,15]
num2 = [i**2 if i == 10 else i-5 if i < 7 else i+5 for i in num1]
print(num2)
# Out:
# [0, 100, 20]

# %% [markdown]
# # lets return pokemon csv and make one more list comprehension example
# # # lets classify pokemons whether they have high or low speed. Our threshold is average speed.****

# %%
threshold = sum(data.Speed)/len(data.Speed)
data["speed_level"] = ["high" if i > threshold else "low" for i in data.Speed]
data.loc[:10,["speed_level","Speed"]] # we will learn loc more detailed later
# Out:
#    speed_level  Speed
# 0          low     45
# 1          low     60
# 2         high     80
# 3         high     80
# 4          low     65
# 5         high     80
# 6         high    100
# 7         high    100
# 8         high    100
# 9          low     43
# 10         low     58

# %% [markdown]
# # **CLEANING DATA**

# %%
data
# Out:
#        #                   Name   Type 1  ... Generation  Legendary  speed_level
# 0      1              Bulbasaur    Grass  ...          1      False          low
# 1      2                Ivysaur    Grass  ...          1      False          low
# 2      3               Venusaur    Grass  ...          1      False         high
# 3      3  VenusaurMega Venusaur    Grass  ...          1      False         high
# 4      4             Charmander     Fire  ...          1      False          low
# ..   ...                    ...      ...  ...        ...        ...          ...
# 795  719                Diancie     Rock  ...          6       True          low
# 796  719    DiancieMega Diancie     Rock  ...          6       True         high
# 797  720    HoopaHoopa Confined  Psychic  ...          6       True         high
# 798  720     HoopaHoopa Unbound  Psychic  ...          6       True         high
# 799  721              Volcanion     Fire  ...          6       True         high
#
# ...

# %%
data.shape
# Out:
# (800, 14)

# %%
data.ndim
# Out:
# 2

# %%
data.sample(10)
# Out:
#        #                 Name    Type 1  ... Generation  Legendary  speed_level
# 467  420              Cherubi     Grass  ...          4      False          low
# 277  256            Combusken      Fire  ...          3      False          low
# 654  593            Jellicent     Water  ...          5      False          low
# 255  236              Tyrogue  Fighting  ...          2      False          low
# 527  475  GalladeMega Gallade   Psychic  ...          4      False         high
# 592  532              Timburr  Fighting  ...          5      False          low
# 530  478             Froslass       Ice  ...          4      False         high
# 37    32             Nidoran♂    Poison  ...          1      False          low
# 203  188             Skiploom     Grass  ...          2      False         high
# 343  314             Illumise       Bug  ...          3      False         high
#
# [10 rows x 14 columns]

# %%
data.columns
# Out:
# Index(['#', 'Name', 'Type 1', 'Type 2', 'Total', 'HP', 'Attack', 'Defense',
#        'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary',
#        'speed_level'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   #            800 non-null    int64
#  1   Name         800 non-null    object
#  2   Type 1       800 non-null    object
#  3   Type 2       414 non-null    object
#  4   Total        800 non-null    int64
#  5   HP           800 non-null    int64
#  6   Attack       800 non-null    int64
#  7   Defense      800 non-null    int64
#  8   Sp. Atk      800 non-null    int64
#  9   Sp. Def      800 non-null    int64
#  10  Speed        800 non-null    int64
#  11  Generation   800 non-null    int64
#  12  Legendary    800 non-null    bool
#  13  speed_level  800 non-null    object
# dtypes: bool(1), int64(9), object(4)
# memory usage: 82.2+ KB

# %% [markdown]
# # **EXPLORATORY DATA ANALYSIS**

# %%
data['Type 1'].value_counts(dropna =False)              # if there are nan values that also be counted
                              # As it can be seen below there are 112 water pokemon or 70 grass pokemon
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Ghost        32
# Dark         31
# Poison       28
# Steel        27
# Fighting     27
# Ice          24
# Fairy        17
# Flying        4
# Name: Type 1, dtype: int64

# %%
data.describe()
# Out:
#                 #      Total          HP  ...     Sp. Def       Speed  Generation
# count  800.000000  800.00000  800.000000  ...  800.000000  800.000000   800.00000
# mean   362.813750  435.10250   69.258750  ...   71.902500   68.277500     3.32375
# std    208.343798  119.96304   25.534669  ...   27.828916   29.060474     1.66129
# min      1.000000  180.00000    1.000000  ...   20.000000    5.000000     1.00000
# 25%    184.750000  330.00000   50.000000  ...   50.000000   45.000000     2.00000
# 50%    364.500000  450.00000   65.000000  ...   70.000000   65.000000     3.00000
# 75%    539.250000  515.00000   80.000000  ...   90.000000   90.000000     5.00000
# max    721.000000  780.00000  255.000000  ...  230.000000  180.000000     6.00000
#
# [8 rows x 9 columns]

# %% [markdown]
# # **VISUAL EXPLORATORY DATA ANALYSIS**

# %%
# For example: compare attack of pokemons that are legendary  or not
# Black line at top is max
# Blue line at top is 75%
# Green line is median (50%)
# Blue line at bottom is 25%
# Black line at bottom is min
# There are no outliers
data.boxplot(column='Attack',by = 'Legendary')

# %% [markdown]
# # **TIDY DATA**
# # **melt()**

# %%
data_new = data.head()   
data_new
# Out:
#    #                   Name Type 1  ... Generation  Legendary  speed_level
# 0  1              Bulbasaur  Grass  ...          1      False          low
# 1  2                Ivysaur  Grass  ...          1      False          low
# 2  3               Venusaur  Grass  ...          1      False         high
# 3  3  VenusaurMega Venusaur  Grass  ...          1      False         high
# 4  4             Charmander   Fire  ...          1      False          low
#
# [5 rows x 14 columns]

# %%
# id_vars = what we do not wish to melt
# value_vars = what we want to melt

# %%
melted = pd.melt(frame=data_new, id_vars = 'Name', value_vars= ['Attack','Defense'])
melted
# Out:
#                     Name variable  value
# 0              Bulbasaur   Attack     49
# 1                Ivysaur   Attack     62
# 2               Venusaur   Attack     82
# 3  VenusaurMega Venusaur   Attack    100
# 4             Charmander   Attack     52
# 5              Bulbasaur  Defense     49
# 6                Ivysaur  Defense     63
# 7               Venusaur  Defense     83
# 8  VenusaurMega Venusaur  Defense    123
# 9             Charmander  Defense     43

# %%
melted = pd.melt(frame=data_new, id_vars = 'Name', value_vars= ['Speed','Defense'])
melted
# Out:
#                     Name variable  value
# 0              Bulbasaur    Speed     45
# 1                Ivysaur    Speed     60
# 2               Venusaur    Speed     80
# 3  VenusaurMega Venusaur    Speed     80
# 4             Charmander    Speed     65
# 5              Bulbasaur  Defense     49
# 6                Ivysaur  Defense     63
# 7               Venusaur  Defense     83
# 8  VenusaurMega Venusaur  Defense    123
# 9             Charmander  Defense     43

# %% [markdown]
# # **PIVOTING DATA**
# # Reverse of melting.

# %%
# Index is name
# I want to make that columns are variable
# Finally values in columns are value
melted.pivot(index = 'Name', columns = 'variable',values='value')
# Out:
# variable               Defense  Speed
# Name
# Bulbasaur                   49     45
# Charmander                  43     65
# Ivysaur                     63     60
# Venusaur                    83     80
# VenusaurMega Venusaur      123     80

# %% [markdown]
# # **CONCATENATING DATA**

# %%
data1 = data.head()
data2= data.tail()
conc_data_row = pd.concat([data1,data2],axis =0,ignore_index =True) # axis = 0 : adds dataframes in row
conc_data_row
# Out:
#      #                   Name   Type 1  ... Generation  Legendary  speed_level
# 0    1              Bulbasaur    Grass  ...          1      False          low
# 1    2                Ivysaur    Grass  ...          1      False          low
# 2    3               Venusaur    Grass  ...          1      False         high
# 3    3  VenusaurMega Venusaur    Grass  ...          1      False         high
# 4    4             Charmander     Fire  ...          1      False          low
# 5  719                Diancie     Rock  ...          6       True          low
# 6  719    DiancieMega Diancie     Rock  ...          6       True         high
# 7  720    HoopaHoopa Confined  Psychic  ...          6       True         high
# 8  720     HoopaHoopa Unbound  Psychic  ...          6       True         high
# 9  721              Volcanion     Fire  ...          6       True         high
#
# [10 rows x 14 columns]

# %%
data1 = data['Attack'].head()
data2= data['Defense'].head()
conc_data_col = pd.concat([data1,data2],axis =1) # axis = 1 : adds dataframes in column
conc_data_col
# Out:
#    Attack  Defense
# 0      49       49
# 1      62       63
# 2      82       83
# 3     100      123
# 4      52       43

# %% [markdown]
# # **DATA TYPES**
#
# There are 5 basic data types: object(string),boolean, integer, float and categorical.
#
# <br> We can make conversion data types like from str to categorical or from int to float
# <br> Why is category important:
# * make dataframe smaller in memory
# * can be utilized for anlaysis especially for sklearn(we will learn later)

# %%
data.dtypes
# Out:
# #               int64
# Name           object
# Type 1         object
# Type 2         object
# Total           int64
# HP              int64
# Attack          int64
# Defense         int64
# Sp. Atk         int64
# Sp. Def         int64
# Speed           int64
# Generation      int64
# Legendary        bool
# speed_level    object
# dtype: object

# %%
# lets convert object(str) to categorical and int to float.

# %%
data['Type 1'] = data['Type 1'].astype('category')
data['Speed'] = data['Speed'].astype('float')

# %%
data.dtypes
# Out:
# #                 int64
# Name             object
# Type 1         category
# Type 2           object
# Total             int64
# HP                int64
# Attack            int64
# Defense           int64
# Sp. Atk           int64
# Sp. Def           int64
# Speed           float64
# Generation        int64
# Legendary          bool
# speed_level      object
# dtype: object

# %% [markdown]
# # # MISSING DATA and TESTING WITH ASSERT
#
# If we encounter with missing data, what we can do:
#
# leave as is
# # drop them with dropna()
#
# # fill missing value with fillna()
#
# # fill missing values with test statistics like mean
#
# Assert statement: check that you can turn on or turn off when you are done with your testing of the program

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 14 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   #            800 non-null    int64
#  1   Name         800 non-null    object
#  2   Type 1       800 non-null    category
#  3   Type 2       414 non-null    object
#  4   Total        800 non-null    int64
#  5   HP           800 non-null    int64
#  6   Attack       800 non-null    int64
#  7   Defense      800 non-null    int64
#  8   Sp. Atk      800 non-null    int64
#  9   Sp. Def      800 non-null    int64
#  10  Speed        800 non-null    float64
#  11  Generation   800 non-null    int64
#  12  Legendary    800 non-null    bool
#  13  speed_level  800 non-null    object
# dtypes: bool(1), category(1), float64(1), int64(8), object(3)
# memory usage: 77.4+ KB

# %%
data["Type 2"].value_counts()   # NAN 'ları göstermemiş
# Out:
# Flying      97
# Ground      35
# Poison      34
# Psychic     33
# Fighting    26
# Grass       25
# Fairy       23
# Steel       22
# Dark        20
# Dragon      18
# Water       14
# Ghost       14
# Ice         14
# Rock        14
# Fire        12
# Electric     6
# Normal       4
# Bug          3
# Name: Type 2, dtype: int64

# %%
data["Type 2"].value_counts(dropna=False) # Eğer NAN varsa drop etme onu da göster !!!!!
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ice          14
# Rock         14
# Water        14
# Ghost        14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
data["Type 2"].dropna(inplace=True)

# %%
data["Type 2"].value_counts(dropna=False)
# Out:
# NaN         386
# Flying       97
# Ground       35
# Poison       34
# Psychic      33
# Fighting     26
# Grass        25
# Fairy        23
# Steel        22
# Dark         20
# Dragon       18
# Ice          14
# Rock         14
# Water        14
# Ghost        14
# Fire         12
# Electric      6
# Normal        4
# Bug           3
# Name: Type 2, dtype: int64

# %%
data["Type 2"].notnull().all()
# Out:
# False

# %%
data["Type 2"].fillna('empty',inplace = True)

# %% [markdown]
# # **PANDAS FOUNDATION**

# %% [markdown]
# As you notice, I do not give all idea in a same time. Although, we learn some basics of pandas, we will go deeper in pandas.
#
# single column = series
# NaN = not a number
# dataframe.values = numpy

# %% [markdown]
# # **BUILDING DATA FRAMES FROM SCRATCH**
#
# We can build data frames from csv as we did earlier.
# Also we can build dataframe from dictionaries
# zip() method: This function returns a list of tuples, where the i-th tuple contains the i-th element from each of the argument sequences or iterables.
# Adding new column
# Broadcasting: Create new column and assign a value to entire column

# %%
country = ["Spain","France"]
population = ["11","12"]
list_label = ["country","population"]
list_col = [country,population]
zipped = list(zip(list_label,list_col))
data_dict = dict(zipped)
df = pd.DataFrame(data_dict)
df
# Out:
#   country population
# 0   Spain         11
# 1  France         12

# %%
# Add new columns
df["capital"] = ["madrid","paris"]
df
# Out:
#   country population capital
# 0   Spain         11  madrid
# 1  France         12   paris

# %%
df["income"] = 0                 #Broadcasting entire column
df
# Out:
#   country population capital  income
# 0   Spain         11  madrid       0
# 1  France         12   paris       0

# %% [markdown]
# ## **VISUAL EXPLORATORY DATA ANALYSIS**
#
# Plot
#
# Subplot
#
# Histogram:

# %% [markdown]
# # **Plotting all data**

# %%
data1 = data.loc[:,["Attack","Defense","Speed"]]
data1.plot()
# it is confusing

# %% [markdown]
# # **subplots**

# %%
data1.plot(subplots = True)
plt.show()

# %% [markdown]
# # **scatter plot**

# %%
data1.plot(kind = "scatter",x="Attack",y = "Defense")
plt.show()

# %% [markdown]
# # **hist plot**

# %%
data1.plot(kind = "hist", y = "Defense",bins = 50,range= (0,250))

# %% [markdown]
# #**Histogram subplot with non cumulative and cumulative**

# %%
fig, axes = plt.subplots(nrows=2,ncols=1)
data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),ax = axes[0])
data1.plot(kind = "hist",y = "Defense",bins = 50,range= (0,250),ax = axes[1],cumulative = True)
plt.savefig('graph.png')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.7/dist-packages/matplotlib/pyplot.py'>

# %% [markdown]
# #  **INDEXING PANDAS TIME SERIES**
#
# * datetime = object
# * parse_dates(boolean): Transform date to ISO 8601 (yyyy-mm-dd hh:mm:ss ) format

# %%
time_list = ["1992-03-08","1992-04-12"]
print(type(time_list[1])) # As you can see date is string
# however we want it to be datetime object
datetime_object = pd.to_datetime(time_list)
print(type(datetime_object))
# Out:
# <class 'str'>
# <class 'pandas.core.indexes.datetimes.DatetimeIndex'>

# %%
# close warning
import warnings
warnings.filterwarnings("ignore")

# %%
# In order to practice lets take head of pokemon data and add it a time list
data2 = data.head()
date_list = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["date"] = datetime_object
# lets make date as index
data2= data2.set_index("date")
data2
# Out:
#             #                   Name Type 1  ... Generation  Legendary  speed_level
# date                                         ...
# 1992-01-10  1              Bulbasaur  Grass  ...          1      False          low
# 1992-02-10  2                Ivysaur  Grass  ...          1      False          low
# 1992-03-10  3               Venusaur  Grass  ...          1      False         high
# 1993-03-15  3  VenusaurMega Venusaur  Grass  ...          1      False         high
# 1993-03-16  4             Charmander   Fire  ...          1      False          low
#
# [5 rows x 14 columns]

# %%
# In order to practice lets take head of pokemon data and add it a time list
data2 = data.head()
date_list = ["1992-01-10","1992-02-10","1992-03-10","1993-03-15","1993-03-16"]
datetime_object = pd.to_datetime(date_list)
data2["date"] = datetime_object

# %%
# lets make date as index
data2= data2.set_index("date")
data2
# Out:
#             #                   Name Type 1  ... Generation  Legendary  speed_level
# date                                         ...
# 1992-01-10  1              Bulbasaur  Grass  ...          1      False          low
# 1992-02-10  2                Ivysaur  Grass  ...          1      False          low
# 1992-03-10  3               Venusaur  Grass  ...          1      False         high
# 1993-03-15  3  VenusaurMega Venusaur  Grass  ...          1      False         high
# 1993-03-16  4             Charmander   Fire  ...          1      False          low
#
# [5 rows x 14 columns]

# %%
# Now we can select according to our date index
print(data2.loc["1993-03-16"])
print(data2.loc["1992-03-10":"1993-03-16"])
# Out:
# #                       4
# Name           Charmander
# Type 1               Fire
# Type 2              empty
# Total                 309
# HP                     39
# Attack                 52
# Defense                43
# Sp. Atk                60
# Sp. Def                50
# Speed                65.0
# Generation              1
# Legendary           False
# speed_level           low
# Name: 1993-03-16 00:00:00, dtype: object
#             #                   Name Type 1  ... Generation  Legendary  speed_level
# date                                         ...
# 1992-03-10  3               Venusaur  Grass  ...          1      False         high
# 1993-03-15  3  VenusaurMega Venusaur  Grass  ...          1      False         high
# 1993-03-16  4             Charmander   Fire  ...          1      False          low
#
# [3 rows x 14 columns]

# %% [markdown]
# # RESAMPLING PANDAS TIME SERIES
#
# Resampling: statistical method over different time intervals
#
#  Needs string to specify frequency like **"M" = month or "A" = year**
#
# Downsampling: reduce date time rows to slower frequency like from daily to weekly
#
# Upsampling: increase date time rows to faster frequency like from daily to hourly
#
# Interpolate: Interpolate values according to different methods like ‘linear’, ‘time’ or index’
#
# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.interpolate.html

# %%
# We will use data2 that we create at previous part
data2.resample("A").mean()
# Out:
#               #  Total         HP  ...      Speed  Generation  Legendary
# date                               ...
# 1992-12-31  2.0  416.0  61.666667  ...  61.666667         1.0        0.0
# 1993-12-31  3.5  467.0  59.500000  ...  72.500000         1.0        0.0
#
# [2 rows x 10 columns]

# %%
# Lets resample with month
data2.resample("M").mean()
# As you can see there are a lot of nan because data2 does not include all months
# Out:
#               #  Total    HP  Attack  ...  Sp. Def  Speed  Generation  Legendary
# date                                  ...
# 1992-01-31  1.0  318.0  45.0    49.0  ...     65.0   45.0         1.0        0.0
# 1992-02-29  2.0  405.0  60.0    62.0  ...     80.0   60.0         1.0        0.0
# 1992-03-31  3.0  525.0  80.0    82.0  ...    100.0   80.0         1.0        0.0
# 1992-04-30  NaN    NaN   NaN     NaN  ...      NaN    NaN         NaN        NaN
# 1992-05-31  NaN    NaN   NaN     NaN  ...      NaN    NaN         NaN        NaN
# 1992-06-30  NaN    NaN   NaN     NaN  ...      NaN    NaN         NaN        NaN
# 1992-07-31  NaN    NaN   NaN     NaN  ...      NaN    NaN         NaN        NaN
# 1992-08-31  NaN    NaN   NaN     NaN  ...      NaN    NaN         NaN        NaN
# 1992-09-30  NaN    NaN   NaN     NaN  ...      NaN    NaN         NaN        NaN
# 1992-10-31  NaN    NaN   NaN     NaN  ...      NaN    NaN         NaN        NaN
# ...

# %%
# In real life (data is real. Not created from us like data2) we can solve this problem with interpolate
# We can interpolete from first value
data2.resample("M").first()
# Out:
#               #                   Name  ... Legendary speed_level
# date                                    ...
# 1992-01-31  1.0              Bulbasaur  ...       0.0         low
# 1992-02-29  2.0                Ivysaur  ...       0.0         low
# 1992-03-31  3.0               Venusaur  ...       0.0        high
# 1992-04-30  NaN                   None  ...       NaN        None
# 1992-05-31  NaN                   None  ...       NaN        None
# 1992-06-30  NaN                   None  ...       NaN        None
# 1992-07-31  NaN                   None  ...       NaN        None
# 1992-08-31  NaN                   None  ...       NaN        None
# 1992-09-30  NaN                   None  ...       NaN        None
# 1992-10-31  NaN                   None  ...       NaN        None
# 1992-11-30  NaN                   None  ...       NaN        None
# 1992-12-31  NaN                   None  ...       NaN        None
# 1993-01-31  NaN                   None  ...       NaN        None
# ...

# %%
# Or we can interpolate with mean()
data2.resample("M").mean().interpolate("linear")
# Out:
#                    #       Total         HP  ...   Speed  Generation  Legendary
# date                                         ...
# 1992-01-31  1.000000  318.000000  45.000000  ...  45.000         1.0        0.0
# 1992-02-29  2.000000  405.000000  60.000000  ...  60.000         1.0        0.0
# 1992-03-31  3.000000  525.000000  80.000000  ...  80.000         1.0        0.0
# 1992-04-30  3.041667  520.166667  78.291667  ...  79.375         1.0        0.0
# 1992-05-31  3.083333  515.333333  76.583333  ...  78.750         1.0        0.0
# 1992-06-30  3.125000  510.500000  74.875000  ...  78.125         1.0        0.0
# 1992-07-31  3.166667  505.666667  73.166667  ...  77.500         1.0        0.0
# 1992-08-31  3.208333  500.833333  71.458333  ...  76.875         1.0        0.0
# 1992-09-30  3.250000  496.000000  69.750000  ...  76.250         1.0        0.0
# 1992-10-31  3.291667  491.166667  68.041667  ...  75.625         1.0        0.0
# ...

# %% [markdown]
# # **MANIPULATING DATA FRAMES WITH PANDAS**

# %% [markdown]
# # **INDEXING DATA FRAMES**
#
# Indexing using square brackets
#
# Using column attribute and row label
#
# Using loc accessor
#
# Selecting only some columns

# %%
data = data.set_index("#")
data.head()
# Out:
#                     Name Type 1  Type 2  ...  Generation  Legendary  speed_level
# #                                        ...
# 1              Bulbasaur  Grass  Poison  ...           1      False          low
# 2                Ivysaur  Grass  Poison  ...           1      False          low
# 3               Venusaur  Grass  Poison  ...           1      False         high
# 3  VenusaurMega Venusaur  Grass  Poison  ...           1      False         high
# 4             Charmander   Fire   empty  ...           1      False          low
#
# [5 rows x 13 columns]

# %%
data["HP"][1]
# Out:
# 45

# %%
data.HP[1]
# Out:
# 45

# %%
data.loc[1,["HP"]]
# Out:
# HP    45
# Name: 1, dtype: object

# %%
data[["HP","Attack"]]
# Out:
#      HP  Attack
# #
# 1    45      49
# 2    60      62
# 3    80      82
# 3    80     100
# 4    39      52
# ..   ..     ...
# 719  50     100
# 719  50     160
# 720  80     110
# 720  80     160
# 721  80     110
#
# [800 rows x 2 columns]

# %%
print(type(data["HP"]))     # series
print(type(data[["HP"]]))   # data frames
# Out:
# <class 'pandas.core.series.Series'>
# <class 'pandas.core.frame.DataFrame'>

# %%
data.loc[1:10, "HP":"Defense"]
# Out:
#     HP  Attack  Defense
# #
# 1   45      49       49
# 2   60      62       63
# 3   80      82       83
# 3   80     100      123
# 4   39      52       43
# 5   58      64       58
# 6   78      84       78
# 6   78     130      111
# 6   78     104       78
# 7   44      48       65
# 8   59      63       80
# 9   79      83      100
# 9   79     103      120
# 10  45      30       35

# %%
data.loc[10:1:-1, "HP":"Defense"]   #reverse
# Out:
#     HP  Attack  Defense
# #
# 10  45      30       35
# 9   79     103      120
# 9   79      83      100
# 8   59      63       80
# 7   44      48       65
# 6   78     104       78
# 6   78     130      111
# 6   78      84       78
# 5   58      64       58
# 4   39      52       43
# 3   80     100      123
# 3   80      82       83
# 2   60      62       63
# 1   45      49       49

# %%
data.loc[1:10, "Speed":]
# Out:
#     Speed  Generation  Legendary speed_level
# #
# 1    45.0           1      False         low
# 2    60.0           1      False         low
# 3    80.0           1      False        high
# 3    80.0           1      False        high
# 4    65.0           1      False         low
# 5    80.0           1      False        high
# 6   100.0           1      False        high
# 6   100.0           1      False        high
# 6   100.0           1      False        high
# 7    43.0           1      False         low
# 8    58.0           1      False         low
# 9    78.0           1      False        high
# 9    78.0           1      False        high
# 10   45.0           1      False         low

# %% [markdown]
# # **FILTERING DATA FRAMES**

# %%
# Creating boolean series
boolean = data.HP > 200
data[boolean]
# Out:
#         Name  Type 1 Type 2  Total  ...  Speed  Generation  Legendary  speed_level
# #                                   ...
# 113  Chansey  Normal  empty    450  ...   50.0           1      False          low
# 242  Blissey  Normal  empty    540  ...   55.0           2      False          low
#
# [2 rows x 13 columns]

# %%
# Combining filters
first_filter = data.HP > 150
second_filter = data.Speed > 35
data[first_filter & second_filter]
# Out:
#           Name  Type 1 Type 2  Total  ...  Speed  Generation  Legendary  speed_level
# #                                     ...
# 113    Chansey  Normal  empty    450  ...   50.0           1      False          low
# 242    Blissey  Normal  empty    540  ...   55.0           2      False          low
# 321    Wailord   Water  empty    500  ...   60.0           3      False          low
# 594  Alomomola   Water  empty    470  ...   65.0           5      False          low
#
# [4 rows x 13 columns]

# %%
data[(data.HP > 150 )& (data.Speed > 35)]
# Out:
#           Name  Type 1 Type 2  Total  ...  Speed  Generation  Legendary  speed_level
# #                                     ...
# 113    Chansey  Normal  empty    450  ...   50.0           1      False          low
# 242    Blissey  Normal  empty    540  ...   55.0           2      False          low
# 321    Wailord   Water  empty    500  ...   60.0           3      False          low
# 594  Alomomola   Water  empty    470  ...   65.0           5      False          low
#
# [4 rows x 13 columns]

# %%
# Filtering column based others
data.HP[data.Speed<15]
# Out:
# #
# 213     20
# 328     45
# 438     50
# 446    135
# 597     44
# Name: HP, dtype: int64

# %% [markdown]
# # **TRANSFORMING DATA**
#
# Plain python functions
#
# Lambda function: to apply arbitrary python function to every element
#
# Defining column using other columns

# %%
def div(n):
    return n/2
data.HP.apply(div)
# Out:
# #
# 1      22.5
# 2      30.0
# 3      40.0
# 3      40.0
# 4      19.5
#        ...
# 719    25.0
# 719    25.0
# 720    40.0
# 720    40.0
# 721    40.0
# Name: HP, Length: 800, dtype: float64

# %%
# Or we can use lambda function
data.HP.apply(lambda n : n/2)
# Out:
# #
# 1      22.5
# 2      30.0
# 3      40.0
# 3      40.0
# 4      19.5
#        ...
# 719    25.0
# 719    25.0
# 720    40.0
# 720    40.0
# 721    40.0
# Name: HP, Length: 800, dtype: float64

# %%
# Defining column using other columns
data["total_power"] = data.Attack + data.Defense
data.head()
# Out:
#                     Name Type 1  Type 2  ...  Legendary  speed_level  total_power
# #                                        ...
# 1              Bulbasaur  Grass  Poison  ...      False          low           98
# 2                Ivysaur  Grass  Poison  ...      False          low          125
# 3               Venusaur  Grass  Poison  ...      False         high          165
# 3  VenusaurMega Venusaur  Grass  Poison  ...      False         high          223
# 4             Charmander   Fire   empty  ...      False          low           95
#
# [5 rows x 14 columns]

# %% [markdown]
# # **INDEX OBJECTS AND LABELED DATA**

# %%
# our index name is this:
print(data.index.name)
# lets change it
data.index.name = "index_name"
data.head()
# Out:
# #
#                              Name Type 1  ... speed_level  total_power
# index_name                                ...
# 1                       Bulbasaur  Grass  ...         low           98
# 2                         Ivysaur  Grass  ...         low          125
# 3                        Venusaur  Grass  ...        high          165
# 3           VenusaurMega Venusaur  Grass  ...        high          223
# 4                      Charmander   Fire  ...         low           95
#
# [5 rows x 14 columns]

# %%
# We can make one of the column as index. I actually did it at the beginning of manipulating data frames with pandas section
# It was like this
# data= data.set_index("#")
# also you can use 
# data.index = data["#"]

# %% [markdown]
# # # **Overwrite index**

# %%
# if we want to modify index we need to change all of them.
data.head()
# first copy of our data to data3 then change index 
data3 = data.copy()
# lets make index start from 100. It is not remarkable change but it is just example
data3.index = range(100,900,1)
data3.head()
# Out:
#                       Name Type 1  Type 2  ...  Legendary  speed_level  total_power
# 100              Bulbasaur  Grass  Poison  ...      False          low           98
# 101                Ivysaur  Grass  Poison  ...      False          low          125
# 102               Venusaur  Grass  Poison  ...      False         high          165
# 103  VenusaurMega Venusaur  Grass  Poison  ...      False         high          223
# 104             Charmander   Fire   empty  ...      False          low           95
#
# [5 rows x 14 columns]

# %% [markdown]
# # **HIERARCHICAL INDEXING**

# %%
# Setting index :      type 1 is outer      type 2 is inner index

data1 = data.set_index(["Type 1","Type 2"]) 
data1.head(100)

# data1.loc["Fire","Flying"] # howw to use indexes
# Out:
#                                 Name  Total  ...  speed_level  total_power
# Type 1 Type 2                                ...
# Grass  Poison              Bulbasaur    318  ...          low           98
#        Poison                Ivysaur    405  ...          low          125
#        Poison               Venusaur    525  ...         high          165
#        Poison  VenusaurMega Venusaur    625  ...         high          223
# Fire   empty              Charmander    309  ...          low           95
# ...                              ...    ...  ...          ...          ...
# Poison empty                  Grimer    325  ...          low          130
#        empty                     Muk    500  ...          low          180
# Water  empty                Shellder    305  ...          low          165
#        Ice                  Cloyster    525  ...         high          275
# Ghost  Poison                 Gastly    310  ...         high           65
#
# ...

# %% [markdown]
# # **PIVOTING DATA FRAMES**

# %%
dic = {"treatment":["A","A","B","B"],"gender":["F","M","F","M"],"response":[10,45,5,9],"age":[15,4,72,65]}
df = pd.DataFrame(dic)
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
# pivoting
df.pivot(index="treatment",columns = "gender",values="response")
# Out:
# gender      F   M
# treatment
# A          10  45
# B           5   9

# %% [markdown]
# # **STACKING and UNSTACKING DATAFRAME**
#
# deal with multi label indexes
#
# level: position of unstacked index
#
# swaplevel: change inner and outer level index position

# %%
df1 = df.set_index(["treatment","gender"])
df1
# lets unstack it
# Out:
#                   response  age
# treatment gender
# A         F             10   15
#           M             45    4
# B         F              5   72
#           M              9   65

# %%
# level determines indexes
df1.unstack(level=0)
# Out:
#           response    age
# treatment        A  B   A   B
# gender
# F               10  5  15  72
# M               45  9   4  65

# %%
df1.unstack(level=1)
# Out:
#           response     age
# gender           F   M   F   M
# treatment
# A               10  45  15   4
# B                5   9  72  65

# %%
# change inner and outer level index position
df2 = df1.swaplevel(0,1)
df2
# Out:
#                   response  age
# gender treatment
# F      A                10   15
# M      A                45    4
# F      B                 5   72
# M      B                 9   65

# %% [markdown]
# # **MELTING DATA FRAMES**
# Reverse of pivoting

# %%
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
# df.pivot(index="treatment",columns = "gender",values="response")
pd.melt(df,id_vars="treatment",value_vars=["age","response"])
# Out:
#   treatment  variable  value
# 0         A       age     15
# 1         A       age      4
# 2         B       age     72
# 3         B       age     65
# 4         A  response     10
# 5         A  response     45
# 6         B  response      5
# 7         B  response      9

# %% [markdown]
# # **CATEGORICALS AND GROUPBY**

# %%
df
# Out:
#   treatment gender  response  age
# 0         A      F        10   15
# 1         A      M        45    4
# 2         B      F         5   72
# 3         B      M         9   65

# %%
# according to treatment take means of other features
df.groupby("treatment").mean()   # mean is aggregation / reduction method
# there are other methods like sum, std,max or min
# Out:
#            response   age
# treatment
# A              27.5   9.5
# B               7.0  68.5

# %%
df.groupby("treatment")["age"].mean()
# Out:
# treatment
# A     9.5
# B    68.5
# Name: age, dtype: float64

# %%
df.groupby("treatment").age.mean()
# Out:
# treatment
# A     9.5
# B    68.5
# Name: age, dtype: float64

# %%
df.groupby("treatment").age.max()
# Out:
# treatment
# A    15
# B    72
# Name: age, dtype: int64

# %%
df.groupby("treatment").age.min()
# Out:
# treatment
# A     4
# B    65
# Name: age, dtype: int64

# %%
df.groupby("treatment")[["age", "response"]].mean()
# Out:
#             age  response
# treatment
# A           9.5      27.5
# B          68.5       7.0

# %%
df.groupby("treatment")[["age", "response"]].min()
# Out:
#            age  response
# treatment
# A            4        10
# B           65         5

# %%
df.info()
# as you can see gender is object
# However if we use groupby, we can convert it categorical data. 
# Because categorical data uses less memory, speed up operations like groupby

#df["gender"] = df["gender"].astype("category")
#df["treatment"] = df["treatment"].astype("category")
#df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   treatment  4 non-null      object
#  1   gender     4 non-null      object
#  2   response   4 non-null      int64
#  3   age        4 non-null      int64
# dtypes: int64(2), object(2)
# memory usage: 256.0+ bytes
